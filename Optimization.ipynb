# %%
import torch

# %%
num_actions = 1000
true_reward = torch.randn(num_actions)
print(true_reward)
# Out:
# tensor([-1.4798e+00,  4.7664e-01,  8.0669e-01, -8.1973e-01, -5.0873e-01,
#         -6.8479e-01, -4.9566e-01,  9.9071e-01, -1.0822e+00,  4.0929e+00,
#         -7.2757e-01, -3.0609e-01,  1.0767e+00, -1.0054e+00,  1.6734e+00,
#          5.2903e-01,  1.3571e+00,  8.9943e-01,  8.4296e-01,  6.9329e-01,
#          7.0159e-01, -4.6549e-01, -6.1975e-01,  5.8377e-01, -1.6866e+00,
#         -4.3608e-01,  1.0308e+00,  3.1325e-01, -1.8313e-01,  8.0652e-01,
#          6.5670e-01,  3.6357e-01, -1.4647e-01,  1.4447e+00,  1.0253e+00,
#         -1.5470e+00,  5.4253e-01, -6.2044e-02, -1.2555e-02,  2.0670e+00,
#         -2.3376e-01,  2.4067e-01, -9.4643e-01,  2.3953e-01,  8.6170e-02,
#         -6.0340e-01, -5.8677e-01,  2.0354e-01, -3.1314e-01,  1.0139e+00,
#         -8.7416e-01,  1.1924e+00, -8.1446e-01,  1.2351e+00,  3.3539e-01,
#         -7.1650e-01,  6.7761e-02,  1.0529e+00,  5.5609e-01,  4.7994e-01,
#         -1.4860e+00, -4.3314e-03,  2.8754e-01, -1.2903e+00,  4.4087e-02,
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(true_reward.numpy())
plt.show()

# %%
plt.hist(true_reward.numpy())
plt.show()

# %%
from torch.distributions import Cauchy
error = Cauchy(loc=0.0, scale=0.01).sample((num_actions,))

# %%
proxy_reward = true_reward - error

# %%
plt.scatter(true_reward.numpy(), proxy_reward.numpy(),c=quannt_prob)
plt.show()

# %%
quannt_prob= proxy_reward > 2
#softmax
#plot soft optimazation
quannt_prob = quannt_prob/torch.sum(quannt_prob)
print(quannt_prob)
# Out:
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0455, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0455, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0455, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
# ...
